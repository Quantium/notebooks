# %% [markdown]
# <a href="https://colab.research.google.com/github/Quantium/notebooks/blob/master/Mathplotlib_and_Seaborn_Darkmode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dark Mode for mathplotlib and seaborn
#
# Insert it after library imports
#
# You should have installed mathplotlib, seaborn is optional.

# %%
#@title Dark Mode
plt.style.use('seaborn-v0_8-whitegrid')

plt.style.use('dark_background')
plt.rcParams.update({
    'axes.edgecolor': 'white',
    'axes.labelcolor': 'white',
    'text.color': 'white',
    'xtick.color': 'white',
    'ytick.color': 'white',
    'grid.color': 'lightgray',
    'grid.linestyle': '--',
    'grid.linewidth': 0.5,
    'lines.linewidth': 1.5,
    'lines.markersize': 5,
    'font.size': 10,
    'figure.figsize': (8, 6),
    'savefig.dpi': 300,
    'savefig.bbox': 'tight',
    'legend.edgecolor': 'white',
    'legend.frameon': True,
    'legend.fancybox': False,
})

#Para as matrices de correlación
dark_cmap = sns.color_palette("binary", as_cmap=True)
